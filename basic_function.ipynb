# %% [markdown]
# # Basic_Function
# * Built-in function
# * print option
# * return option
# * list passing
# * dict passing
# * multiple list and dict passing

# %%
len("sanowar")#built-in function
# Out:
# 7

# %%
print("sdafsadfdsa")#built-in function
# Out:
# sdafsadfdsa

# %%
#define function
def test(): 
    pass

# %%
#define function
def test1():
    print("this is my first fun")

# %%
#call function
test1()
# Out:
# this is my first fun

# %%
a = test1()
# Out:
# this is my first fun

# %%
test1()+"sanowar"
# Out:
# this is my first fun
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_98135/2700770913.py in <module>
# ----> 1 test1()+"sanowar"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
"sanowar" + "hossain"
# Out:
# 'sanowarhossain'

# %%
type(test1())
# Out:
# this is my first fun
# NoneType

# %%
a = test1()
# Out:
# this is my first fun

# %%
str(a)
# Out:
# 'None'

# %%
#return the function;always return original value like int, str, float, but print return none type
def test2():
    return "this is my first fun"

# %%
type(test2())
# Out:
# str

# %%
test2() + "sanowar"
# Out:
# 'this is my first funsanowar'

# %%
def test3() : 
    return 235435

# %%
type(test3())
# Out:
# int

# %%
def test4():
    return 4,3, "sanowar" , [1,2,3,4,5]

# %%
b = test4()

# %%
b
# Out:
# (4, 3, 'sanowar', [1, 2, 3, 4, 5])

# %%
b[1]
# Out:
# 3

# %%
b[3]
# Out:
# [1, 2, 3, 4, 5]

# %%
test4()
# Out:
# (4, 3, 'sanowar', [1, 2, 3, 4, 5])

# %%
a = 1
b  = 5 
c = "sanowar"
d = [345354,435435,543,543,5435]

# %%
a ,b,c,d = 34, 45, "sanowar" , "dfasdfa"

# %%
x,y,u,v= test4()

# %%
x
# Out:
# 4

# %%
y
# Out:
# 3

# %%
u
# Out:
# 'sanowar'

# %%
v
# Out:
# [1, 2, 3, 4, 5]

# %%
def test5():
    a = 6*7 /6
    return a

# %%
test5()
# Out:
# 7.0

# %%
len(v)
# Out:
# 5

# %%
l = [3,4,5,6,7,7 ,"sanowar" , [1,3,4,54,56]]

# %%
def test6(a):
    n = []
    if type(a) == list:
        for i in a:
            if type(i) == int:
                n.append(i)
                
    return n

# %%
type(test6(l))
# Out:
# list

# %%
test6([2,3,3,4,56,76,7,"dsfdsf" , ("fdsf","fsdf" , 45)])
# Out:
# [2, 3, 3, 4, 56, 76, 7]

# %%
def test7(a):
    n =[]
    if type(a) == list:
        for i in a:
            if type(i) == int:
                n.append(i)
    return n

# %%
test7(l)
# Out:
# [3, 4, 5, 6, 7, 7]

# %%
l = [3,4,5,6,7,7,"sanowar",[1,3,4,54,56],6,7]
def test6(a):
    n = []
    if type(a) == list:
        for i in a:
            if type(i) == int:
                n.append(i)
            elif type(i) == list:
                for j in i:
                    if type(j) == int:
                        n.append(j)
    return n

# %%
test6(l)
# Out:
# [3, 4, 5, 6, 7, 7, 1, 3, 4, 54, 56, 6, 7]

# %%
def test6(a):
    n = []
    if type(l) == list:
        for i in a:
            if type(i) == int:
                n.append(i)
       
    return n

# %%
test6(l)
# Out:
# [3, 4, 5, 6, 7, 7, 6, 7]

# %%
def test6():
    a = input()
    b = []
    if type(a) ==  int:
        for i in a:
            b.append()
        
    return b

# %%
def test6(a):
    n="sardar"
    if type(a)==list:
        for i in a:
            if type(i)==int:
                n.append(i)
    return n

# %%
def test6(a):
    if type(a)==list:
        for i in l:
            if type(i)==int:
                   n = print(i,end=" ")
    return n

# %%
def test8(c) :
    if type(c) == dict :
        return c.keys()
    else :
        return "you have not passed a dic"

# %%
test8("fsadfsaf")
# Out:
# 'you have not passed a dic'

# %%
test8({"a":"dsfsf" , "b" :2354234 , "c" : [4,5,76,78]})
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
def test9(a,b) :
    if type(a) == list and type(b) == list:
        a.extend(b)
        return a
    else :
        return "either of your data is not a list "

# %%
test9(2424,"uisdeh")
# Out:
# 'either of your data is not a list '

# %%
test9([2,3,4,5,6] , [4,5,7,788])
# Out:
# [2, 3, 4, 5, 6, 4, 5, 7, 788]

# %%
a = [2,3,4,5,6]
b = [4,5,7,788]

# %%
test9(a,b)
# Out:
# [2, 3, 4, 5, 6, 4, 5, 7, 788]

# %%
a
# Out:
# [2, 3, 4, 5, 6, 4, 5, 7, 788]

# %%
def Create_Triangle(row_num):
    n= row_num
    k = n - 1
    
    for i in range(0, n):

        for j in range(0, k):
            print(end=" ")
     
        k = k - 1
     
        for j in range(0, i+1):        
            print("* ", end="")
     
        print("\n")

Create_Triangle(3)
# Out:
#   *
#
#  * *
#
# * * *

# %%
Create_Triangle(10)
# Out:
#          *
#
#         * *
#
#        * * *
#
#       * * * *
#
#      * * * * *
#
#     * * * * * *
#
#    * * * * * * *
#
#   * * * * * * * *
#
#  * * * * * * * * *
#
# * * * * * * * * * *

# %%
Create_Triangle(5)
# Out:
#     *
#
#    * *
#
#   * * *
#
#  * * * *
#
# * * * * *

# %%
def test10(n):
    """
    this is a fun to craete a tri 
    you can give input as an int 
    and you will be able to get output as a traingle 
    """
    for i in range(0,n):
        for j in range (0, i+1):
            print("*", end= "")
        print("\r")

# %%
test10(40)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# *********************
# **********************
# ***********************
# ************************
# *************************
# **************************
# ***************************
# ****************************
# *****************************
# ******************************
# *******************************
# ********************************
# *********************************
# **********************************
# ***********************************
# ************************************
# *************************************
# **************************************
# ***************************************
# ****************************************

# %%
help(test10)
# Out:
# Help on function test10 in module __main__:
#
# test10(n)
#     this is a fun to craete a tri
#     you can give input as an int
#     and you will be able to get output as a traingle

# %%
"""fsad
dsafsa
fsa
fsad
fas
df
asdfasf"""
# Out:
# 'fsad\ndsafsa\nfsa\nfsad\nfas\ndf\nasdfasf'

# %%
help(test10(5))
# Out:
# *
# **
# ***
# ****
# *****
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
help(test10)
# Out:
# Help on function test10 in module __main__:
#
# test10(n)
#     this is a fun to craete a tri
#     you can give input as an int
#     and you will be able to get output as a traingle

# %% [markdown]
# 1 . you have to write a fun which will take string and return a len of
# it without using a inbuilt fun len
# 2 . write a fun which will be able to print an index of all premitive element which you will pass
# 3 . Write a fun which will take input as a dict and give me out as a list of all the values
# even in case of 2 level nesting it should work .
# 4 . write a fun which will take another function as an input and return me an output
# 5. write a function whihc will take multiple list as a input and give me concatnation of all the element as
# and output
# 6 . write a function which will be able to take a list as an input return an index of each element
# like a inbuilt index function but even if we have repetative element it should return index
# 7 . Write a function which will whould return list of all the file name from a directory .
# 8  . write a function which will be able to show your system configuration .
# 9 . write a function which will be able to show date and time  .
# 10 . write a function whihc will be able to read a image file and show it to you .
# 11 . write a function which can read video file and play for you .
# 12  . write a function whihc can move a file from one directory to another directory .
# 13 . write a function which will be able to shutdonw your system .
# 14 . write a function whihc will be able to access your mail .
# 15 . write a func bywhcih i can send a mail to anyone
# 16. write a func to read a complete PDf file .
# 17. write a function to read a word file .
# 18 . write a function which can help you to filter only word file from a directory .
# 19 . write a function by which you can print an ip address of your system .
# 20 . write a function by which you will be able to append two PDF files .
