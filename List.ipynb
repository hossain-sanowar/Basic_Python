# %% [markdown]
# # List
# * Slicing/Indexing
# * Mutable
# * Builting function
# * List Compression

# %% [markdown]
# * Indexing
# <----------(-2)-(-1)-0-1-2-3-4-5-6-7-8------->
# * increasing by 1 bydefault if don't set the range
# * we can set range like b[-1:-4:-1]
# * [start:end:stop]

# %% [markdown]
# Python offers the subsequent list functions:
#
# https://www.analyticsvidhya.com/blog/2021/06/15-functions-you-should-know-to-master-lists-in-python/
#
# * sort(): Sorts the list in ascending order.
# * type(list): It returns the class type of an object.
# * append(): Adds one element to a list.
# * extend(): Adds multiple elements to a list.
# * index(): Returns the first appearance of a particular value.
# * max(list): It returns an item from the list with a max value.
# * min(list): It returns an item from the list with a min value.
# * len(list): It gives the overall length of the list.
# * clear(): Removes all the elements from the list.
# * insert(): Adds a component at the required position.
# * count(): Returns the number of elements with the required value.
# * pop(): Removes the element at the required position.
# * remove(): Removes the primary item with the desired value.
# * reverse(): Reverses the order of the list.
# * copy():  Returns a duplicate of the list.

# %% [markdown]
# List Refresher
# It is the primary, and certainly the foremost common container.
#
# * A list is defined as an ordered, mutable, and heterogeneous collection of objects.
# * To clarify: order implies that the gathering of objects follow a particular order
# * Mutable means the list can be mutated or changed, and heterogeneous implies that you’ll be able to mix and match any kind of object, or data type, within a list (int, float, or string).
# * Lists are contained within a collection of square brackets [ ].
# * Python Lists - javatpoint
# ![image.png](attachment:image.png)

# %% [markdown]
# # <----------(-2)-(-1)-0-1-2-3-4-5-6-7-8------->
# * increasing by 1 bydefault if don't set the range
# * we can set range like b[-1:-4:-1]

# %%
l = ["sanowar" , "hossain" , 3543 , 4+6j , True , 345.56]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 'sanowar'

# %%
l[-1]
# Out:
# 345.56

# %%
l[-5]
# Out:
# 'hossain'

# %%
l
# Out:
# ['sanowar', 'hossain', 3543, (4+6j), True, 345.56]

# %%
l[0:4]
# Out:
# ['sanowar', 'hossain', 3543, (4+6j)]

# %%
l[::-1]
# Out:
# [345.56, True, (4+6j), 3543, 'hossain', 'sanowar']

# %%
l[-1:6]
# Out:
# [345.56]

# %%
type(l[0])
# Out:
# str

# %%
type(l[4])
# Out:
# bool

# %%
l[0][1]
# Out:
# 'a'

# %%
#complex number
l[3].imag
# Out:
# 6.0

# %%
l1 = ["sanowar" , "hossain" , 4356]
l2 = ["xyz" , "pqr" , 546.567]

# %%
l1+l2
# Out:
# ['sanowar', 'hossain', 4356, 'xyz', 'pqr', 546.567]

# %%
l1 + ["sanowar"]
# Out:
# ['sanowar', 'hossain', 4356, 'sanowar']

# %%
l1*2
# Out:
# ['sanowar', 'hossain', 4356, 'sanowar', 'hossain', 4356]

# %%
l1
# Out:
# ['sanowar', 'hossain', 4356]

# %%
l1[0] =4356455634564

# %%
l1
# Out:
# [4356455634564, 'hossain', 4356]

# %%
l1[1]
# Out:
# 'hossain'

# %%
s = "sanowar"

# %%
#Str is immuteable

# %%
s[0] = "k"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_97433/132523510.py in <module>
# ----> 1 s[0] = "k"
#
# TypeError: 'str' object does not support item assignment

# %%
l1
# Out:
# [4356455634564, 'kumar', 4356]

# %%
l[1] = "sanowar"

# %%
s.replace('s','v')
# Out:
# 'vanowar'

# %%
s
# Out:
# 'sanowar'

# %%
s[0] = 'v'#string is not replace
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_97433/1429152404.py in <module>
# ----> 1 s[0] = 'v'#string is not replace
#
# TypeError: 'str' object does not support item assignment

# %%
l1
# Out:
# [4356455634564, 'hossain', 4356]

# %%
len(l1)
# Out:
# 3

# %%
 345 in l1
# Out:
# False

# %%
l = ['okay','kumar', 78,45,789,5.5,True, 5+8j]
l[-1:6:-1]
# Out:
# [(5+8j)]

# %%
l2
# Out:
# ['xyz', 'pqr', 546.567]

# %%
l2.append("sanowar")

# %%
l2
# Out:
# ['xyz', 'pqr', 546.567, 'sanowar']

# %%
l2.pop()
# Out:
# 'sanowar'

# %%
l2.pop(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_97433/2175636296.py in <module>
# ----> 1 l2.pop(3)
#
# IndexError: pop index out of range

# %%
l2.pop(2)
# Out:
# 546.567

# %%
l2
# Out:
# ['xyz', 'pqr']

# %%
l2
# Out:
# ['xyz', 'pqr']

# %%
l2.append(345435)

# %%
l2
# Out:
# ['xyz', 'pqr', 345435]

# %%
l2.insert(1,"dsgadfgda")

# %%
l2
# Out:
# ['xyz', 'dsgadfgda', 'pqr', 345435]

# %%
l2.insert(3,[34,45,56,576,67])

# %%
l2
# Out:
# ['xyz', 'dsgadfgda', 'pqr', [34, 45, 56, 576, 67], 345435]

# %%
l2
# Out:
# ['xyz', 'dsgadfgda', 'pqr', [34, 45, 56, 576, 67], 345435]

# %%
l2[::-1]
# Out:
# [345435, [34, 45, 56, 576, 67], 'pqr', 'dsgadfgda', 'xyz']

# %%
l2.reverse()

# %%
l2
# Out:
# [345435, [34, 45, 56, 576, 67], 'pqr', 'dsgadfgda', 'xyz']

# %%
l1
# Out:
# [4356455634564, 'hossain', 4356]

# %%
l2
# Out:
# [345435, [34, 45, 56, 576, 67], 'pqr', 'dsgadfgda', 'xyz']

# %%
l2[1][2]
# Out:
# 56

# %%
l2
# Out:
# [345435, [34, 45, 56, 576, 67], 'pqr', 'dsgadfgda', 'xyz']

# %%
l2.count('xfddsfsfyz')
# Out:
# 0

# %%
l2.append("dssafasf")

# %%
l2
# Out:
# [345435, [34, 45, 56, 576, 67], 'pqr', 'dsgadfgda', 'xyz', 'dssafasf']

# %%
l2.append([3,4,54,6])

# %%
l2
# Out:
# [345435,
#  [34, 45, 56, 576, 67],
#  'pqr',
#  'dsgadfgda',
#  'xyz',
#  'dssafasf',
#  [3, 4, 54, 6]]

# %%
l1
# Out:
# [4356455634564, 'hossain', 4356]

# %%
l1.extend([2,54,656, "sdfs"])#add more than one

# %%
l1
# Out:
# [4356455634564, 'hossain', 4356, 2, 54, 656, 'sdfs']

# %%
print(l2.reverse()) #??
# Out:
# None

# %%
l1=[43,4343]
#l1+list('sanowar')
l1+['sanowar']
# Out:
# [43, 4343, 'sanowar']

# %%
list("sudh")
# Out:
# ['s', 'u', 'd', 'h']

# %%
s.endswith("")
# Out:
# True

# %%
s
# Out:
# 'sanowar'

# %%
l = ["sudh " , 345,4354353,4353]

# %%
l.append("kumar")

# %%
l
# Out:
# ['sudh ', 345, 4354353, 4353, 'kumar']

# %%
[2,3,4,4,5,76]  + [4,5,6,77]
# Out:
# [2, 3, 4, 4, 5, 76, 4, 5, 6, 77]

# %%
"fdsaffsafsafd afsa saf asdfa sdsaf afsad ".split('&')
# Out:
# ['fdsaffsafsafd afsa saf asdfa sdsaf afsad ']

# %%
3 +4j
# Out:
# (3+4j)

# %%
L=['sudh', 'kumar', 3543, 4+6j, True, 345.6]
L[-1:6]
# Out:
# [345.6]

# %%
kumar in L
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_97433/1415144990.py in <module>
# ----> 1 kumar in L
#
# NameError: name 'kumar' is not defined

# %%
"dfdasfasfda\tsafasf\t\tfadsfsafdsaf\t".expandtabs()
# Out:
# 'dfdasfasfda     safasf          fadsfsafdsaf    '

# %%
a = "I am working in ineuron"

# %%
# a[0:-10:-1] gives blank but a[0:-100:-1] gives ‘I’
# Can you please explain this?
a[0:-24:-1]
# Out:
# 'I'

# %%
a = "I am working in ineuron"

# %%
a[0:-10:-1]
# Out:
# ''

# %%
a[0:-100:-1]
# Out:
# 'I'

# %%
a[0::-1]
# Out:
# 'I'

# %%
l2=['prweu', 5345]
l3=l2
l3[0]='newatl3'
print(l3)
print(l2)
o/p ['newatl3', 5345]
o/p ['newatl3', 5345] 
#why it has changed l2?


s1='sudh'
s2=s1
s2='newdata'
print(s1)                 #in this case why it has not changed s1?
print(s2)
'sudh'
'newdata'
# Out:
# ['newatl3', 5345]
# ['newatl3', 5345]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_97433/709729373.py in <module>
#       4 print(l3)
#       5 print(l2)
# ----> 6 o/p ['newatl3', 5345]
#       7 o/p ['newatl3', 5345]
#       8 #why it has changed l2?
#
# NameError: name 'o' is not defined

# %%
l2=['prweu', 5345]
l3=l2

# %%
l2
# Out:
# ['prweu', 5345]

# %%
l3
# Out:
# ['prweu', 5345]

# %%
l3 = [4,5,6,7,7]

# %%
l3[0] = "dsfdsafsa"

# %%
l3[0] = "sudh"

# %%
l3
# Out:
# ['sudh', 5, 6, 7, 7]

# %%
l2
# Out:
# ['prweu', 5345]

# %%
s1='sudh'
s2=s1
s2='newdata'

# %%
s2
# Out:
# 'newdata'

# %%
s1
# Out:
# 'sudh'

# %%
l1= [569, "Sudh", "ravi"]

# %%
g = l1[2].replace('v',"s")

# %%
l1.pop()
# Out:
# 'ravi'

# %%
l1.append(g)

# %%
l1.pop(2)
# Out:
# 'rasi'

# %%
l1
# Out:
# [569, 'Sudh']

# %%
l=['ved', 12,True]
l[0]=str(l[0].replace('e', 'E') )

# %%
l
# Out:
# ['vEd', 12, True]

# %%
s = 'USA fdf'

# %%
s.isupper()
# Out:
# False

# %%
l = ["sunny" , "gadhiya" , "9999" , 9+9j , True , 99.9]

# %%
l[3].imag
# Out:
# 9.0

# %%
l[3].real
# Out:
# 9.0

# %%
s = ['abc','pqr','xyz']
s.pop(1)
# Out:
# 'pqr'

# %%
" ".join("sudh") + " "
# Out:
# 's u d h '

# %%
s
# Out:
# ['abc', 'xyz']

# %%
s = "sudh"

# %%
s.index('d')
# Out:
# 2

# %%
l = [3,4,5,6]

# %%
l.index(5)
# Out:
# 2

# %%
s = "sudh"

# %%
l1=[2,3,4]

# %%
l2 = [43,4343]
l2+list('sudh')
l1+['sudh']
# Out:
# [2, 3, 4, 'sudh']

# %%
l1= [43,4343]

# %%
l1+list('sudh')
# Out:
# [43, 4343, 's', 'u', 'd', 'h']

# %%
list("sudh")
# Out:
# ['s', 'u', 'd', 'h']

# %%
l1+['sudh']
# Out:
# [43, 4343, 'sudh']

# %%
list("sudh")
# Out:
# ['s', 'u', 'd', 'h']

# %%
l = [4,5,6,6]

# %%
l.insert(-1,45)

# %%
l
# Out:
# [4, 5, 6, 45, 6]

# %%
l.insert(3,"sudh")

# %%
l
# Out:
# [4, 5, 6, 'sudh', 45, 6]

# %%
type(l[3])
# Out:
# str

# %%
s = "sudh"

# %%
l2 =[1,2]
l2[2] = 3 #Why can't assign l2[2] = 3
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_97433/4227495410.py in <module>
#       1 l2 =[1,2]
# ----> 2 l2[2] = 3 #Why can't assign l2[2] = 3
#
# IndexError: list assignment index out of range

# %%
a = 'i am working with ineuron'
a[-5:5:-1]
# Out:
# 'eni htiw gnikro'

# %%
list2=[1,2,3,4,5]

# %%
list2
# Out:
# [1, 2, 3, 4, 5]
